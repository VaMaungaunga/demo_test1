# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # John Maungaunga
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because i want be involved in making informed decisions using data in the area of financial inclusion using mobile money and mobile banking

# %% [markdown]
# ### Subtracting 2 numbers

# %%
a = 2
b =3
print (a-b)
# Out:
# -1

# %% [markdown]
# Bulleted list
# - Mango
# - peach
# - banana
# Numbered list
# 1. Mango
# 2. Bnana
# 3. peach
#
# *** This is the horizantal rule
